# %%
import os
import pandas as pd

# %%
# 1. '..' sube de 'notebooks' a 'EDA'
# 2. Luego entra a 'data', 'raw' y busca el archivo
path = os.path.join("..", "data", "raw", "sampler.csv")

df = pd.read_csv(path)

# %%
print(df.head())
# Out:
#    Year numeric Year categorical         Region  Gender   Age Age categorical  \
# 0             9          Year 09       Auckland    male  14.0          Age 14
# 1            10          Year 10  Bay of Plenty  female  14.0          Age 14
# 2             6          Year 06       Auckland    male  10.0          Age 10
# 3             8          Year 08      Southland    male  13.0          Age 13
# 4             9          Year 09       Auckland  female  14.0          Age 14
#
#         Country New Zealand European Maori Samoan  ...  \
# 0   New Zealand                  yes    no     no  ...
# 1   New Zealand                  yes   yes     no  ...
# 2   New Zealand                  yes    no     no  ...
# 3   New Zealand                  yes    no     no  ...
# 4  Cook Islands                  yes   yes     no  ...
#
#   How true: It is easy for me to make friends  \
# 0                                        17.0
# 1                                        77.0
# ...
